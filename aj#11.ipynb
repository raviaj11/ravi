# %%
mark={"kannada":120,
      "english":90,
      "hindi":91,
      "maths":94,
      "science":95,
      "social":79
      }
print(mark)
mark["sanskrit"]=95
print(mark)
# Out:
# {'kannada': 120, 'english': 90, 'hindi': 91, 'maths': 94, 'science': 95, 'social': 79}
# {'kannada': 120, 'english': 90, 'hindi': 91, 'maths': 94, 'science': 95, 'social': 79, 'sanskrit': 95}

# %%
coordinates=(25,36,7,54,66,78)
print(coordinates[3])
# Out:
# 54

# %%
student={"name":"ravi aj",
       "age":20,
        "course":"bsc,msc"
         }

print(student["course"])
print(student["name"])
# Out:
# bsc,msc
# ravi aj

# %%
age=int(input("enter age"))
if age<=6:
  print("no ticket")
elif age>6 and age<=12:

  print("half ticket")
else:
    print("full ticket")
# Out:
# enter age15
# full ticket

# %%
fruits=["apple","banana","grapes","pineapple"]
print(fruits[2])
fruits.remove("grapes")
print(fruits)
print(fruits[2])
# Out:
# grapes
# ['apple', 'banana', 'pineapple']
# pineapple
