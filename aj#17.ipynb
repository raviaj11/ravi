# %%
for i in range(3):
  for j in range(4):
    print(i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 0 3
# 1 0
# 1 1
# 1 2
# 1 3
# 2 0
# 2 1
# 2 2
# 2 3

# %%
for i in range(2):
 for j in range(2):
  print("*",end="")
  print()
# Out:
# *
# *
# *
# *

# %%
rows=int(input("enter rows"))
cols=int(input("enter columns"))
for i in range(rows):
  for j in range(cols):
    print("*",end="")
    print()
# Out:
# enter rows3
# enter columns3
# *
# *
# *
# *
# *
# *
# *
# *
# *

# %%
for i in range(2):
   j=0
while j<2:
  print(i,j)
  j+=1
# Out:
# 1 0
# 1 1
