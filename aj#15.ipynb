# %%
import numpy as np
scores=[10,12,18,20]
print(np.mean(scores))
# Out:
# 15.0

# %%
from statistics import mode
votes=[1,1,2,3,4,4,4,5,5,5,5,]
most_common=mode(votes)
print(most_common)
# Out:
# 5

# %%
import numpy as np
tight_data=[60,30,50,20]
spread_data=[20,40,50,70]
print ("tight std:",np.std(tight_data))
print ("spread std:",np.std(spread_data))
# Out:
# tight std: 15.811388300841896
# spread std: 18.027756377319946

# %%
import random
#simulating random prediction
for i in range(10):
 prediction=random.choice(["spam","not spam"])
 print(f"email{i+1}:{prediction}")
# Out:
# email1:spam
# email2:spam
# email3:spam
# email4:spam
# email5:spam
# email6:not spam
# email7:not spam
# email8:not spam
# email9:not spam
# email10:not spam

# %%
import random
#simulate 10dice rolls
samples=[random.randint(1,2)
 for _ in range(5)]
print("samples rolls:",samples)
print("samples mean:",sum (samples)/len(samples))
# Out:
# samples rolls: [2, 1, 2, 1, 1]
# samples mean: 1.4
