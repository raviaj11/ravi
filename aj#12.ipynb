# %%
word="raviaj"
print(word[0])
print(word[2])
# Out:
# r
# v

# %%
text="raviaj"
print(text[0:3])
# Out:
# rav

# %%
name="mysuru"
print(len(name))
# Out:
# 6

# %%
text="kumar raja"
text=text.upper()
print(text)
# Out:
# KUMAR RAJA

# %%
data=" kumar  "
print(data.rstrip())
# Out:
#  kumar

# %%
msg="i love sst"
print(msg.replace("sst","aiml"))
# Out:
# i love aiml

# %%
sentance="python is very easy"
words=sentance.split()
print(words)
# Out:
# ['python', 'is', 'very', 'easy']

# %%
email="rhemant222E$gmail.com"
print("@"in email)
# Out:
# False

# %%
words=["python","is","fun"]
print("".join(words))
# Out:
# pythonisfun

# %%
first="python"
second="is"
third="very"
fourth="easy"
print(first+""+second+""+third+""+fourth)
# Out:
# pythonisveryeasy

# %%
name="raviaj"
age=20
print("my name is (hemanth) and iam (20) years old")
# Out:
# my name is (hemanth) and iam (20) years old
