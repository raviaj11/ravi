# %%
fruits=["apple","banana","mango"]
vegetable=["garlic","chilli","onion","carrot"]
print(fruits[0],vegetable[2],vegetable[3])
# Out:
# apple onion carrot

# %%
fruits=["apple","banana","mango"]
vegetable=["garlic","chilli","onion","carrot"]
fruits.append("orange")
print(fruits[3],vegetable[0])
# Out:
# orange garlic

# %%
students=["ravi","rahul","dharani"]
students.append("sarnisha")
print(students)
# Out:
# ['ravi', 'rahul', 'dharani', 'sarnisha']

# %%
number={1,2,3,2,3,4,5,2,1,6,4}
print(number)
number.add(9)
print(number)
number.remove(6)
print(number)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6, 9}
# {1, 2, 3, 4, 5, 9}

# %%
students={"name":"ravi",
          "age":20,
          "course":"bsc",


      }
print(students["course"])
# Out:
# bsc
